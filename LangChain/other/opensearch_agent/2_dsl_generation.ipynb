# %% [markdown]
# [Sample dataset: recipes](https://docs.aiven.io/docs/products/opensearch/howto/sample-dataset)

# %%
# !pip install opensearch-py

# %%
import os,openai,json
from dotenv import find_dotenv,load_dotenv
load_dotenv(find_dotenv())

openai.api_key = os.environ['OPENAI_API_KEY']
from langchain.chat_models import ChatOpenAI
from langchain.prompts.chat import HumanMessage

from opensearchpy import OpenSearch

# %%
SERVICE_URI = 'localhost:9200'
INDEX_NAME = 'epicurious-recipes'
os_client = OpenSearch(hosts=SERVICE_URI, ssl_enable=True)

# %%
INDEX_NAME = 'epicurious-recipes'
mapping_data = os_client.indices.get_mapping(INDEX_NAME)
mappings = mapping_data[INDEX_NAME]['mappings']
# print(json.dumps(mappings,indent=2))

# %%
DSL_TEMPLATE = """\
Given an input question, create a syntactically correct Elasticsearch query to run. \
Unless the user specifies in their question a specific number of examples they wish to obtain, \
always limit your query to at most {top_k} results. \
You can order the results by a relevant column to return the most interesting examples in the database.

Unless told to do not query for all the columns from a specific index, \
only ask for a the few relevant columns given the question.

Pay attention to use only the column names that you can see in the mapping description. \
Be careful to not query for columns that do not exist. Also, pay attention to which column is in which index. \
Return the query as valid json.

Use the following format:

Question: Question here
ESQuery: Elasticsearch Query formatted as json

Mapping: {mapping}

Question: {input}
ESQuery:
"""

# %%
def get_os_dsl(query,k):
    prompt = DSL_TEMPLATE.format(
        top_k=k,
        mapping=json.dumps(mappings,indent=2),
        input=query
    )
    chat = ChatOpenAI()
    messages = [HumanMessage(content=prompt)]
    response = chat(messages)
    # print(response.content)
    return response.content

# %%
import langchain; langchain.debug = True

# %%
top_k = 100
query = '2010年以降のレシピのうち、カロリーが高い順に100個のレシピのカロリーの散布図を書いてください。'
dsl = get_os_dsl(query,top_k)
print(dsl)
# Out:
# [llm/start] [1:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Given an input question, create a syntactically correct Elasticsearch query to run. Unless the user specifies in their question a specific number of examples they wish to obtain, always limit your query to at most 100 results. You can order the results by a relevant column to return the most interesting examples in the database.\n\nUnless told to do not query for all the columns from a specific index, only ask for a the few relevant columns given the question.\n\nPay attention to use only the column names that you can see in the mapping description. Be careful to not query for columns that do not exist. Also, pay attention to which column is in which index. Return the query as valid json.\n\nUse the following format:\n\nQuestion: Question here\nESQuery: Elasticsearch Query formatted as json\n\nMapping: {\n  \"properties\": {\n    \"calories\": {\n      \"type\": \"float\"\n    },\n    \"categories\": {\n      \"type\": \"text\",\n      \"fields\": {\n        \"keyword\": {\n          \"type\": \"keyword\",\n          \"ignore_above\": 256\n        }\n      }\n    },\n    \"date\": {\n      \"type\": \"date\"\n    },\n    \"desc\": {\n      \"type\": \"text\",\n      \"fields\": {\n        \"keyword\": {\n          \"type\": \"keyword\",\n          \"ignore_above\": 256\n        }\n      }\n    },\n    \"directions\": {\n      \"type\": \"text\",\n      \"fields\": {\n        \"keyword\": {\n          \"type\": \"keyword\",\n          \"ignore_above\": 256\n        }\n      }\n    },\n    \"fat\": {\n      \"type\": \"float\"\n    },\n    \"ingredients\": {\n      \"type\": \"text\",\n      \"fields\": {\n        \"keyword\": {\n          \"type\": \"keyword\",\n          \"ignore_above\": 256\n        }\n      }\n    },\n    \"protein\": {\n      \"type\": \"float\"\n    },\n    \"rating\": {\n      \"type\": \"float\"\n    },\n    \"sodium\": {\n      \"type\": \"float\"\n    },\n    \"title\": {\n      \"type\": \"text\",\n      \"fields\": {\n        \"keyword\": {\n          \"type\": \"keyword\",\n          \"ignore_above\": 256\n        }\n      }\n    }\n  }\n}\n\nQuestion: 2010年以降のレシピのうち、カロリーが高い順に100個のレシピのカロリーの散布図を書いてください。\nESQuery:"
#   ]
# }
# [llm/end] [1:llm:ChatOpenAI] [2.72s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "{\n  \"size\": 100,\n  \"query\": {\n    \"range\": {\n      \"date\": {\n        \"gte\": \"2010-01-01\"\n      }\n    }\n  },\n  \"sort\": [\n    {\n      \"calories\": {\n        \"order\": \"desc\"\n      }\n    }\n  ],\n  \"_source\": [\"calories\"]\n}",
#         "generation_info": {
#           "finish_reason": "stop"
#         },
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "{\n  \"size\": 100,\n  \"query\": {\n    \"range\": {\n      \"date\": {\n        \"gte\": \"2010-01-01\"\n      }\n    }\n  },\n  \"sort\": [\n    {\n      \"calories\": {\n        \"order\": \"desc\"\n      }\n    }\n  ],\n  \"_source\": [\"calories\"]\n}",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 532,
#       "completion_tokens": 76,
#       "total_tokens": 608
#     },
#     "model_name": "gpt-3.5-turbo"
#   },
#   "run": null
# }
# {
#   "size": 100,
#   "query": {
#     "range": {
#       "date": {
#         "gte": "2010-01-01"
#       }
#     }
#   },
#   "sort": [
#     {
#       "calories": {
#         "order": "desc"
#       }
#     }
#   ],
#   "_source": ["calories"]
# }

# %%
res = os_client.search(index=INDEX_NAME,body=dsl)
print(json.dumps(res,indent=2))
# Out:
# {
#   "took": 18,
#   "timed_out": false,
#   "_shards": {
#     "total": 1,
#     "successful": 1,
#     "skipped": 0,
#     "failed": 0
#   },
#   "hits": {
#     "total": {
#       "value": 3948,
#       "relation": "eq"
#     },
#     "max_score": null,
#     "hits": [
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Od0xdokBfefTV2V6DEJk",
#         "_score": null,
#         "_source": {
#           "calories": 12213.0
#         },
#         "sort": [
#           12213.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Ct0xdokBfefTV2V6DlF1",
#         "_score": null,
#         "_source": {
#           "calories": 11453.0
#         },
#         "sort": [
#           11453.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "ON0xdokBfefTV2V6DlJ1",
#         "_score": null,
#         "_source": {
#           "calories": 8858.0
#         },
#         "sort": [
#           8858.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "WN0xdokBfefTV2V6BSD5",
#         "_score": null,
#         "_source": {
#           "calories": 8624.0
#         },
#         "sort": [
#           8624.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "890xdokBfefTV2V6CjVd",
#         "_score": null,
#         "_source": {
#           "calories": 8275.0
#         },
#         "sort": [
#           8275.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Od0xdokBfefTV2V6EWOH",
#         "_score": null,
#         "_source": {
#           "calories": 7202.0
#         },
#         "sort": [
#           7202.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "6N0xdokBfefTV2V6BiOc",
#         "_score": null,
#         "_source": {
#           "calories": 6929.0
#         },
#         "sort": [
#           6929.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "FN0xdokBfefTV2V6Bibp",
#         "_score": null,
#         "_source": {
#           "calories": 6173.0
#         },
#         "sort": [
#           6173.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "-t0xdokBfefTV2V6Czkn",
#         "_score": null,
#         "_source": {
#           "calories": 5921.0
#         },
#         "sort": [
#           5921.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "H90xdokBfefTV2V6EWA_",
#         "_score": null,
#         "_source": {
#           "calories": 5897.0
#         },
#         "sort": [
#           5897.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "fN0xdokBfefTV2V6Czon",
#         "_score": null,
#         "_source": {
#           "calories": 5828.0
#         },
#         "sort": [
#           5828.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "8d0xdokBfefTV2V6CjfR",
#         "_score": null,
#         "_source": {
#           "calories": 5604.0
#         },
#         "sort": [
#           5604.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "hN0xdokBfefTV2V6EWOH",
#         "_score": null,
#         "_source": {
#           "calories": 5578.0
#         },
#         "sort": [
#           5578.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "8d0xdokBfefTV2V6DD8f",
#         "_score": null,
#         "_source": {
#           "calories": 5509.0
#         },
#         "sort": [
#           5509.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "9d0xdokBfefTV2V6CjRd",
#         "_score": null,
#         "_source": {
#           "calories": 5474.0
#         },
#         "sort": [
#           5474.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "ut0xdokBfefTV2V6DlF1",
#         "_score": null,
#         "_source": {
#           "calories": 5455.0
#         },
#         "sort": [
#           5455.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "e90xdokBfefTV2V6DEJk",
#         "_score": null,
#         "_source": {
#           "calories": 5449.0
#         },
#         "sort": [
#           5449.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "290xdokBfefTV2V6BBnh",
#         "_score": null,
#         "_source": {
#           "calories": 5090.0
#         },
#         "sort": [
#           5090.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "ud0xdokBfefTV2V6DU31",
#         "_score": null,
#         "_source": {
#           "calories": 5060.0
#         },
#         "sort": [
#           5060.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Zd0xdokBfefTV2V6EFo_",
#         "_score": null,
#         "_source": {
#           "calories": 4889.0
#         },
#         "sort": [
#           4889.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "cd0xdokBfefTV2V6BBrh",
#         "_score": null,
#         "_source": {
#           "calories": 4570.0
#         },
#         "sort": [
#           4570.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "u90xdokBfefTV2V6Byc2",
#         "_score": null,
#         "_source": {
#           "calories": 4524.0
#         },
#         "sort": [
#           4524.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Dd0xdokBfefTV2V6EWTJ",
#         "_score": null,
#         "_source": {
#           "calories": 4494.0
#         },
#         "sort": [
#           4494.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "1d0xdokBfefTV2V6BR2l",
#         "_score": null,
#         "_source": {
#           "calories": 4396.0
#         },
#         "sort": [
#           4396.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "QN0xdokBfefTV2V6DEJk",
#         "_score": null,
#         "_source": {
#           "calories": 4325.0
#         },
#         "sort": [
#           4325.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "-t0xdokBfefTV2V6Byg2",
#         "_score": null,
#         "_source": {
#           "calories": 4157.0
#         },
#         "sort": [
#           4157.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "q90xdokBfefTV2V6EWOH",
#         "_score": null,
#         "_source": {
#           "calories": 3935.0
#         },
#         "sort": [
#           3935.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "I90xdokBfefTV2V6BBvh",
#         "_score": null,
#         "_source": {
#           "calories": 3809.0
#         },
#         "sort": [
#           3809.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "tt0xdokBfefTV2V6CTE7",
#         "_score": null,
#         "_source": {
#           "calories": 3388.0
#         },
#         "sort": [
#           3388.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "X90xdokBfefTV2V6BiJM",
#         "_score": null,
#         "_source": {
#           "calories": 3128.0
#         },
#         "sort": [
#           3128.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "vt0xdokBfefTV2V6D1UA",
#         "_score": null,
#         "_source": {
#           "calories": 2925.0
#         },
#         "sort": [
#           2925.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "5N0xdokBfefTV2V6CTI8",
#         "_score": null,
#         "_source": {
#           "calories": 2856.0
#         },
#         "sort": [
#           2856.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "L90xdokBfefTV2V6Czkn",
#         "_score": null,
#         "_source": {
#           "calories": 2800.0
#         },
#         "sort": [
#           2800.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "590xdokBfefTV2V6D1jB",
#         "_score": null,
#         "_source": {
#           "calories": 2754.0
#         },
#         "sort": [
#           2754.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "8d0xdokBfefTV2V6DUq0",
#         "_score": null,
#         "_source": {
#           "calories": 2715.0
#         },
#         "sort": [
#           2715.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "V90xdokBfefTV2V6EWA_",
#         "_score": null,
#         "_source": {
#           "calories": 2677.0
#         },
#         "sort": [
#           2677.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "sd0xdokBfefTV2V6BiJM",
#         "_score": null,
#         "_source": {
#           "calories": 2675.0
#         },
#         "sort": [
#           2675.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "JN0xdokBfefTV2V6DlF1",
#         "_score": null,
#         "_source": {
#           "calories": 2612.0
#         },
#         "sort": [
#           2612.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "ot0xdokBfefTV2V6DUu0",
#         "_score": null,
#         "_source": {
#           "calories": 2550.0
#         },
#         "sort": [
#           2550.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Et0xdokBfefTV2V6CjVd",
#         "_score": null,
#         "_source": {
#           "calories": 2543.0
#         },
#         "sort": [
#           2543.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "bd0xdokBfefTV2V6Byqz",
#         "_score": null,
#         "_source": {
#           "calories": 2484.0
#         },
#         "sort": [
#           2484.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "V90xdokBfefTV2V6Cz3U",
#         "_score": null,
#         "_source": {
#           "calories": 2484.0
#         },
#         "sort": [
#           2484.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "h90xdokBfefTV2V6DEXk",
#         "_score": null,
#         "_source": {
#           "calories": 2477.0
#         },
#         "sort": [
#           2477.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "oN0xdokBfefTV2V6DlO4",
#         "_score": null,
#         "_source": {
#           "calories": 2448.0
#         },
#         "sort": [
#           2448.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Bd0xdokBfefTV2V6EWXJ",
#         "_score": null,
#         "_source": {
#           "calories": 2368.0
#         },
#         "sort": [
#           2368.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "a90xdokBfefTV2V6DEOk",
#         "_score": null,
#         "_source": {
#           "calories": 2359.0
#         },
#         "sort": [
#           2359.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "it0xdokBfefTV2V6CC5r",
#         "_score": null,
#         "_source": {
#           "calories": 2351.0
#         },
#         "sort": [
#           2351.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "e90xdokBfefTV2V6Czon",
#         "_score": null,
#         "_source": {
#           "calories": 2341.0
#         },
#         "sort": [
#           2341.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Nt0xdokBfefTV2V6BSH6",
#         "_score": null,
#         "_source": {
#           "calories": 2308.0
#         },
#         "sort": [
#           2308.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "B90xdokBfefTV2V6DEJk",
#         "_score": null,
#         "_source": {
#           "calories": 2293.0
#         },
#         "sort": [
#           2293.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "z90xdokBfefTV2V6BBrh",
#         "_score": null,
#         "_source": {
#           "calories": 2291.0
#         },
#         "sort": [
#           2291.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "6d0xdokBfefTV2V6DETj",
#         "_score": null,
#         "_source": {
#           "calories": 2278.0
#         },
#         "sort": [
#           2278.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "390xdokBfefTV2V6BSD6",
#         "_score": null,
#         "_source": {
#           "calories": 2213.0
#         },
#         "sort": [
#           2213.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "F90xdokBfefTV2V6CDDD",
#         "_score": null,
#         "_source": {
#           "calories": 2193.0
#         },
#         "sort": [
#           2193.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "P90xdokBfefTV2V6Cz7U",
#         "_score": null,
#         "_source": {
#           "calories": 2184.0
#         },
#         "sort": [
#           2184.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "cN0xdokBfefTV2V6CzyB",
#         "_score": null,
#         "_source": {
#           "calories": 2137.0
#         },
#         "sort": [
#           2137.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "md0xdokBfefTV2V6EFym",
#         "_score": null,
#         "_source": {
#           "calories": 2123.0
#         },
#         "sort": [
#           2123.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "ct0xdokBfefTV2V6BSD5",
#         "_score": null,
#         "_source": {
#           "calories": 2036.0
#         },
#         "sort": [
#           2036.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "9N0xdokBfefTV2V6DEKk",
#         "_score": null,
#         "_source": {
#           "calories": 2018.0
#         },
#         "sort": [
#           2018.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "M90xdokBfefTV2V6DUpt",
#         "_score": null,
#         "_source": {
#           "calories": 2007.0
#         },
#         "sort": [
#           2007.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "p90xdokBfefTV2V6Byqz",
#         "_score": null,
#         "_source": {
#           "calories": 2005.0
#         },
#         "sort": [
#           2005.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Y90xdokBfefTV2V6EF71",
#         "_score": null,
#         "_source": {
#           "calories": 2002.0
#         },
#         "sort": [
#           2002.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "b90xdokBfefTV2V6CjZd",
#         "_score": null,
#         "_source": {
#           "calories": 1958.0
#         },
#         "sort": [
#           1958.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "D90xdokBfefTV2V6EF2m",
#         "_score": null,
#         "_source": {
#           "calories": 1951.0
#         },
#         "sort": [
#           1951.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "R90xdokBfefTV2V6EFym",
#         "_score": null,
#         "_source": {
#           "calories": 1943.0
#         },
#         "sort": [
#           1943.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "IN0xdokBfefTV2V6CTPS",
#         "_score": null,
#         "_source": {
#           "calories": 1933.0
#         },
#         "sort": [
#           1933.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "8d0xdokBfefTV2V6Byc2",
#         "_score": null,
#         "_source": {
#           "calories": 1920.0
#         },
#         "sort": [
#           1920.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "sd0xdokBfefTV2V6BiFM",
#         "_score": null,
#         "_source": {
#           "calories": 1898.0
#         },
#         "sort": [
#           1898.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "QN0xdokBfefTV2V6Czkn",
#         "_score": null,
#         "_source": {
#           "calories": 1873.0
#         },
#         "sort": [
#           1873.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "hN0xdokBfefTV2V6CDDD",
#         "_score": null,
#         "_source": {
#           "calories": 1842.0
#         },
#         "sort": [
#           1842.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Jt0xdokBfefTV2V6Cz7U",
#         "_score": null,
#         "_source": {
#           "calories": 1822.0
#         },
#         "sort": [
#           1822.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "0t0xdokBfefTV2V6DD8f",
#         "_score": null,
#         "_source": {
#           "calories": 1821.0
#         },
#         "sort": [
#           1821.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "dt0xdokBfefTV2V6CTE7",
#         "_score": null,
#         "_source": {
#           "calories": 1783.0
#         },
#         "sort": [
#           1783.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Id0xdokBfefTV2V6DEXk",
#         "_score": null,
#         "_source": {
#           "calories": 1781.0
#         },
#         "sort": [
#           1781.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "I90xdokBfefTV2V6BR6l",
#         "_score": null,
#         "_source": {
#           "calories": 1765.0
#         },
#         "sort": [
#           1765.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "id0xdokBfefTV2V6CTPS",
#         "_score": null,
#         "_source": {
#           "calories": 1763.0
#         },
#         "sort": [
#           1763.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "oN0xdokBfefTV2V6EF_2",
#         "_score": null,
#         "_source": {
#           "calories": 1763.0
#         },
#         "sort": [
#           1763.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "BN0xdokBfefTV2V6DEAf",
#         "_score": null,
#         "_source": {
#           "calories": 1743.0
#         },
#         "sort": [
#           1743.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Jd0xdokBfefTV2V6DEXk",
#         "_score": null,
#         "_source": {
#           "calories": 1742.0
#         },
#         "sort": [
#           1742.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "M90xdokBfefTV2V6CjjR",
#         "_score": null,
#         "_source": {
#           "calories": 1740.0
#         },
#         "sort": [
#           1740.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "I90xdokBfefTV2V6DUlt",
#         "_score": null,
#         "_source": {
#           "calories": 1739.0
#         },
#         "sort": [
#           1739.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "lt0xdokBfefTV2V6CjfR",
#         "_score": null,
#         "_source": {
#           "calories": 1735.0
#         },
#         "sort": [
#           1735.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "yN0xdokBfefTV2V6DUz0",
#         "_score": null,
#         "_source": {
#           "calories": 1726.0
#         },
#         "sort": [
#           1726.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "CN0xdokBfefTV2V6CzyB",
#         "_score": null,
#         "_source": {
#           "calories": 1725.0
#         },
#         "sort": [
#           1725.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "S90xdokBfefTV2V6EWOH",
#         "_score": null,
#         "_source": {
#           "calories": 1717.0
#         },
#         "sort": [
#           1717.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Mt0xdokBfefTV2V6BR1M",
#         "_score": null,
#         "_source": {
#           "calories": 1715.0
#         },
#         "sort": [
#           1715.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "V90xdokBfefTV2V6CCwL",
#         "_score": null,
#         "_source": {
#           "calories": 1702.0
#         },
#         "sort": [
#           1702.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Vd0xdokBfefTV2V6BBrh",
#         "_score": null,
#         "_source": {
#           "calories": 1699.0
#         },
#         "sort": [
#           1699.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Y90xdokBfefTV2V6EWOH",
#         "_score": null,
#         "_source": {
#           "calories": 1682.0
#         },
#         "sort": [
#           1682.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "5t0xdokBfefTV2V6Byc2",
#         "_score": null,
#         "_source": {
#           "calories": 1667.0
#         },
#         "sort": [
#           1667.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Pt0xdokBfefTV2V6CTE7",
#         "_score": null,
#         "_source": {
#           "calories": 1637.0
#         },
#         "sort": [
#           1637.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "zd0xdokBfefTV2V6Axhe",
#         "_score": null,
#         "_source": {
#           "calories": 1630.0
#         },
#         "sort": [
#           1630.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "y90xdokBfefTV2V6BiSc",
#         "_score": null,
#         "_source": {
#           "calories": 1628.0
#         },
#         "sort": [
#           1628.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "Md0xdokBfefTV2V6DlT_",
#         "_score": null,
#         "_source": {
#           "calories": 1620.0
#         },
#         "sort": [
#           1620.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "8t0xdokBfefTV2V6CDDD",
#         "_score": null,
#         "_source": {
#           "calories": 1600.0
#         },
#         "sort": [
#           1600.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "6d0xdokBfefTV2V6CTI8",
#         "_score": null,
#         "_source": {
#           "calories": 1599.0
#         },
#         "sort": [
#           1599.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "e90xdokBfefTV2V6Dk8y",
#         "_score": null,
#         "_source": {
#           "calories": 1599.0
#         },
#         "sort": [
#           1599.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "td0xdokBfefTV2V6CzuB",
#         "_score": null,
#         "_source": {
#           "calories": 1597.0
#         },
#         "sort": [
#           1597.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "XN0xdokBfefTV2V6D1UA",
#         "_score": null,
#         "_source": {
#           "calories": 1597.0
#         },
#         "sort": [
#           1597.0
#         ]
#       },
#       {
#         "_index": "epicurious-recipes",
#         "_id": "8N0xdokBfefTV2V6EWKH",
#         "_score": null,
#         "_source": {
#           "calories": 1591.0
#         },
#         "sort": [
#           1591.0
#         ]
#       }
#     ]
#   }
# }
